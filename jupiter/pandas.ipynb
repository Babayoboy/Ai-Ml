# %%
import pandas as pd

# %%
series1 = pd.Series([1,2,3,4,5])
print(series)
print(type(series))

# index
print(series[0])
print(series[3])

# %%
series2 = pd.Series([23, 24, 25, 26], index=["Adam", "Eve", "Bob", "Charlie"])
print(series2)
print(series2["Bob"])

# %%
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series([10,9,8,7,6])

s1+s2

s1[0] = 100
changed_s1 = s1.drop(0)

print(s1)
print(changed_s1)

# %%
# Dataframe

info = {
    "Name": ["Ansh", "Nandani", "Shivam"],
    "Age": [20,19,21],
    "CGPA": [7.5, 9.5, 8.5],
}

df = pd.DataFrame(info)
print(type(df))
print(df.index)
print(df.columns)

# %%
df

# %%
df2 = pd.DataFrame([["Ansh", 20], ["Nandani", 19], ["Shivam", 21]], columns=["Name", "Age"])

# %%
df2

# %%
import numpy as np

np_arr = np.array([[1,2,3], [4,5,6]])

df3 = pd.DataFrame(np_arr, columns=["A","B","C"])

# %%
df3

# %%
# CSV  data

df4 = pd.read_csv("employee_data.csv")
print(df4, type(df4))

# %%
df4.head() # Rows from top
df4.tail() # Rows From bottom
df4.sample(5) # Random Rows

df4.info() # Gives info of the dataframe
df4.shape
df4.describe()
df4.columns
df4.nunique()
